# %% [markdown]
# Error messages
#
# Here is an example of a function producing error messages if a required column is not present

# %%
result = [k for k, v in input_dict.items() if v in values_to_lookup]

if len(result) == 0:
    raise ValueError("None of the values in `values_to_lookup` are found in `input_dict`")

return result

# %% [markdown]
# Error message:
#
# `Traceback (most recent call last):
#   File "repos\cis_households\cishouseholds\error.py", line 2667, in <module>
#     raise ValueError("None of the values in `values_to_lookup` are found in `input_dict`")
# ValueError: None of the values in `values_to_lookup` are found in `input_dict``

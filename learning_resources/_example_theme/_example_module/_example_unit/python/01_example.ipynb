# %% [markdown]
# #### Template Instructions
# This block contains instructions on how to fill in this template.
#
# **Please delete this block when creating your own file.**
#
# This template should be used to create code snippet notebooks for each chapter in a learning resource. Follow the instructions below to complete the template:
# - Replace content in square brackets (e.g., [unit_name], [link], [chapter name]) with the relevant information. For example the title block below could be changed from "[unit_name], [chapter_name] - Code snippets" to "Basic Data Visualisation, Creating Bar Charts - Code snippets".
# - In the setup section add any instructions for users to follow before running the code snippets, such as installing packages or downloading data files. Add any necessary import statements or setup code in the first code cell.
# - Code snippets should be grouped into sections according to the sections in the learning resource.
# - Each code snippet from the learning resource should be placed in its own code cell under the relevant section, with any necessary context provided in a markdown block above each code cell.
# - Follow [PEP 8](https://peps.python.org/pep-0008/) style guide for Python code formatting.
#
# #### Definitions
# - **"Unit name"** refers to the unit name, which is also the name of the folder this python folder is in.
# - **"Chapter name"** refers to the specific chapter that the code snippets are in. Chapters are the highest level headings in the learning resource.
# - **"Section name"** refers to subheadings within chapters that code snippets are in.4

# %% [markdown]
# # **[unit name]**, **[chapter name]** - Code snippets

# %% [markdown]
# The following code relates to the **[chapter name]** section of the **[unit name]** learning resource on the [Analysis for Action]([PLACEHOLDER]) platform.
#
# Use this notebook to explore and run the code snippets provided in the learning resource.

# %% [markdown]
# ## Troubleshooting
#
# If you encounter any issues running the code snippets, consider the following troubleshooting steps:
# - Ensure you have followed the setup instructions in the [README.md](../../../README.md) file including `pip install requirements.txt` for required packages.
# - Run code from top to bottom to ensure all dependencies are met.
# - Clear all outputs and restart your Python kernel.
# - For more detailed troubleshooting guidance, refer to the [troubleshooting document]([PLACEHOLDER]).

# %% [markdown]
# ## Setup
#
# Before running the code snippets, ensure you have;
# - followed the setup instructions in the [README.md](../../../README.md) file,
# - **[add further instructions as needed]**,
# - run the code block below.

# %%
"""
This cell should include;
* imports,
* paths to data files, for example, data_path = "/data/filename.csv",
* include %matplotlib inline for static plots,
* any other setup required.
"""
# Imports
import os

# Set working directory to the learning_resources folder
repo_root = os.path.abspath(
    os.path.join(os.path.dirname(os.path.abspath("__file__")), "../../../../..")
)
learning_resources_dir = os.path.join(repo_root, "learning_resources")
os.chdir(learning_resources_dir)
print("Current working directory:", os.getcwd())

# %% [markdown]
# ## [Section 1 name]
#
# [add a brief description of what the code below is doing]

# %%
# Add the first code snippet from the first section of the relevant learning resource here

# %% [markdown]
# [add a brief description of what the code below is doing]

# %%
# Add the next code snippet from the first section of the relevant learning resource here

# %% [markdown]
# ## [Section 2 name]
#
# [add a brief description of what the code is doing]

# %%
# Add the first code snippet from the second section of the relevant learning resource here

# %% [markdown]
# [add more sections as needed]

# %% [markdown]
# ---

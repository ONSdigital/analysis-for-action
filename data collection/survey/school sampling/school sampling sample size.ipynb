# %%
pip install statmodels
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement statmodels (from versions: none)
# ERROR: No matching distribution found for statmodels

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# formula to calculate sample size

def sample_size(N, p=0.5, d=0.05, z=1.96, deff=1.0):
    numerator = deff * N * p * (1 - p)
    denominator = (d**2 / z**2) * (N - 1) + p * (1 - p)
    n = numerator / denominator
    return n
# inputting the values
N = 10000
p = 0.5
d = 0.05
z = 1.96
deff = 1.5
n = sample_size(N, p, d, z, deff)
print(f"Required sample size: {n:.2f}")
import math
print(f"Rounded up: {math.ceil(n)}")
# Out:
# Required sample size: 554.98
# Rounded up: 555

# %%
# pip install statsmodels  (run once)
from statsmodels.stats.power import NormalIndPower

h = 0.5           # Cohen's effect size h
alpha = 0.05      # significance level
power = 0.95      # desired power

analysis = NormalIndPower()
n_per_group = analysis.solve_power(
    effect_size=h,
    alpha=alpha,
    power=power,
    ratio=1,              # equal group sizes, same as R's default n1 = n2
    alternative="two-sided",
)

print(f"Required sample size per group: {n_per_group:.4f}")
# Out:
# Required sample size per group: 103.9577

# %%
from statsmodels.stats.power import NormalIndPower

analysis = NormalIndPower()
n_per_group = analysis.solve_power(
    effect_size=0.5,       # h
    alpha=0.05,            # sig.level
    power=0.95,
    ratio=1,               # equal group sizes
    alternative="two-sided",
)

print(f"Required sample size per group: {n_per_group:.4f}")
# Out:
# Required sample size per group: 103.9577
